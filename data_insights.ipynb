# %% [markdown]
# # Data Insights
# Here we can do different things to explore the data without having to add them to the actual app.

# %%
# Import modules
import pandas as pd
import seaborn

# %%
# Read in the data
df = pd.read_csv('data/rental_data.csv')

# %% [markdown]
# # Cost-Population Relationship
# Does there seem to be any relationship between cost and population at the county level. If it does, is it consistent across number of bedrooms?
#
# There doesn't seem to be much connection.

# %%
df_popsort = df[['pop2023', 'fmr_1', 'fmr_2', 'fmr_3', 'fmr_4']].sort_values('pop2023').sample(100)
seaborn.lineplot(df_popsort, y='pop2023', x='fmr_1')
#seaborn.lineplot(df_popsort, x='pop2023', y='fmr_2')
#seaborn.lineplot(df_popsort, x='pop2023', y='fmr_3')
#seaborn.lineplot(df_popsort, x='pop2023', y='fmr_4')
# Out:
# <Axes: xlabel='fmr_1', ylabel='pop2023'>
